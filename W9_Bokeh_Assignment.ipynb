# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?

# %% [markdown]
# #### Solution -

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import show,figure,output_file

# %%
x  =[1,2,3,4,5]
y= [5,6,7,8,3]

# %%
p = figure()
p.line(x,y)
show(p)
# Out:
#   <div id="da6a987d-b4b2-46ca-b30b-6fc2e717d1b6" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.

# %% [markdown]
# #### Solution -

# %% [markdown]
# Glyphs in the bokeh plot are visual markers used to represent data points on a plot.

# %%
p = figure()
p.square(x,y,size = 10)
show(p)
# Out:
#   <div id="cd6c48fc-1020-4f00-9742-0070750fa143" data-root-id="p1127" style="display: contents;"></div>

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %% [markdown]
# #### Solution -

# %%
p = figure(title = "customize appearance")
p.xaxis.axis_label="x axis"
p.yaxis.axis_label="y axis"
p.circle(x,y,legend_label="custome",size = 10)
show(p)
# Out:
#   <div id="ac02a90d-7c28-45e9-9912-36db6a7391c1" data-root-id="p1168" style="display: contents;"></div>

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
# real time?

# %% [markdown]
# #### Solution -

# %% [markdown]
# I am not able to solve this question because I have not done this kind of study yet.

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?

# %% [markdown]
# #### Solution -

# %% [markdown]
# I am not able to solve this question because I have not done this kind of study yet.
