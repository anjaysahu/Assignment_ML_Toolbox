# %% [markdown]
# Q1. Create a Pandas Series that contains the following data: 4, 8, 15, 16, 23, and 42. Then, print the series.

# %% [markdown]
# #### Answer -

# %%
import pandas as pd

# %%
data = {"ser":[4, 8, 15, 16, 23, 42]}

# %%
se = pd.Series(data)

# %%
print(se)
# Out:
# ser    [4, 8, 15, 16, 23, 42]
# dtype: object

# %%
type(se)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Q2. Create a variable of list type containing 10 elements in it, and apply pandas.Series function on the variable print it.

# %% [markdown]
# #### Answer -

# %%
l = [5,6,55.6,4.65,"anjay","sahu","new","my",8,10]

# %%
nps = pd.Series(l)

# %%
nps
# Out:
# 0        5
# 1        6
# 2     55.6
# 3     4.65
# 4    anjay
# 5     sahu
# 6      new
# 7       my
# 8        8
# 9       10
# dtype: object

# %% [markdown]
# Q3. Create a Pandas DataFrame that contains the following data:
# ![image.png](attachment:96d5a1db-666d-4352-84ac-e29751ea571f.png)
#
# Then, print the DataFrame.

# %% [markdown]
# #### Answer -

# %%
data1 = {"Name" : ["Alice","Bob","Claire"],
        "Age"   : [25, 30, 27],
        "Gender": ["Female", "Male", "Female"]}

# %%
df = pd.DataFrame(data1)

# %%
df
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %% [markdown]
# Q4. What is ‘DataFrame’ in pandas and how is it different from pandas.series Explain with an example.

# %% [markdown]
# #### Answer -

# %% [markdown]
# In pandas, DataFrame is a 2-dimensional data structure format, on the other hand, pandas.series is 1-dimensional format data.

# %%
data1 = {"Name" : ["Alice","Bob","Claire"],
        "Age"   : [25, 30, 27],
        "Gender": ["Female", "Male", "Female"]}

# %% [markdown]
# **DataFrame example :-**

# %%
pd.DataFrame(data1)
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %% [markdown]
# **Series example :-**

# %%
pd.Series([2,5,9,8,10])
# Out:
# 0     2
# 1     5
# 2     9
# 3     8
# 4    10
# dtype: int64

# %% [markdown]
# Q5. What are some common functions you can use to manipulate data in a Pandas DataFrame? Can you give an example of when you might use one of these functions?

# %% [markdown]
# #### Answer -

# %% [markdown]
# We use Categorical and unique function for manipulate data in a Pandas DataFrame. They both are fimd unique thing.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(df["Pclass"])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df["Pclass"].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# Q6. Which of the following is mutable in nature Series, DataFrame, Panel?

# %% [markdown]
# #### Answer -

# %% [markdown]
# Series and DataFrame are mutable.

# %% [markdown]
# Q7. Create a DataFrame using multiple Series. Explain with an example.

# %% [markdown]
# #### Answer -

# %%
s1 = pd.Series(["aj","ram","anjay"])

# %%
s2 = pd.Series([10, 23, 26])

# %%
s3 = pd.Series([5 , 2 , 8])

# %%
df1 = pd.DataFrame({"Name":s1,"Age":s2,"id_n":s3})

# %%
df1
# Out:
#     Name  Age  id_n
# 0     aj   10     5
# 1    ram   23     2
# 2  anjay   26     8
